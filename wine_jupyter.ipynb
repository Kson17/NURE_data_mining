# %%
import pandas as pd

# %%
attributes = ['Class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium',
              'Total phenols', 'Flavanoids', 'Nonflavanoid phenols', 'Proanthocyanins',
              'Color intensity', 'Hue', 'OD280/OD315 of diluted wines', 'Proline']

# %%
df = pd.read_csv('wine.data', header=None)

# %%
df.columns = attributes

# %%
df
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
# Диапазоны значений атрибутов
pd.DataFrame([df.max(), df.min()], ['Max', 'Min'])
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# Max    3.0    14.83        5.80  3.23               30.0      162.0
# Min    1.0    11.03        0.74  1.36               10.6       70.0
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# Max           3.88        5.08                  0.66             3.58
# Min           0.98        0.34                  0.13             0.41
#
#      Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# Max            13.00  1.71                          4.00   1680.0
# Min             1.28  0.48                          1.27    278.0

# %%
# Alcohol
boxplot=df.boxplot(column='Alcohol')

# %%
# Malic acid
boxplot=df.boxplot(column='Malic acid')

# %%
# Ash
boxplot=df.boxplot(column='Ash')

# %%
# Alcalinity of ash
boxplot=df.boxplot(column='Alcalinity of ash')

# %%
# Magnesium
boxplot=df.boxplot(column='Magnesium')

# %%
# Total phenols
boxplot=df.boxplot(column='Total phenols')

# %%
# Flavanoids
boxplot=df.boxplot(column='Flavanoids')

# %%
# Nonflavanoid phenols
boxplot=df.boxplot(column='Nonflavanoid phenols')

# %%
# Proanthocyanins
boxplot=df.boxplot(column='Proanthocyanins')

# %%
# Color intensity
boxplot=df.boxplot(column='Color intensity')

# %%
# Hue
boxplot=df.boxplot(column='Hue')

# %%
# OD280/OD315 of diluted wines
boxplot=df.boxplot(column='OD280/OD315 of diluted wines')

# %%
# Proline
boxplot=df.boxplot(column='Proline')

# %%
# Целевой атрибут - 'Class'
# Целью иссследования было классифицировать виды вина на основе его состава

# Выделено 3 класса

boxplot=df.boxplot(column='Class')

# %%
df.drop(df.columns[0], axis=1, inplace=True)

# %%
# 3.1 - 3.6 

pd.DataFrame(
    [df.max(),
    df.min(),
    df.mean(),
    df.median(),
    (df.max() + df.min()) / 2,
    df.std(),
    df.mad(),
    df.max() - df.min(),
    df.var()], 
    ['Max', 'Min', 'Среднее значение','Медиана', 'Полусумма крайних значений', 
     'Среднее квадратическое отклонение', 'Средний модуль отклонения', 
     'Размах', 'Дисперсия']
)
# Out:
#                                      Alcohol  Malic acid       Ash  \
# Max                                14.830000    5.800000  3.230000
# Min                                11.030000    0.740000  1.360000
# Среднее значение                   13.000618    2.336348  2.366517
# Медиана                            13.050000    1.865000  2.360000
# Полусумма крайних значений         12.930000    3.270000  2.295000
# Среднее квадратическое отклонение   0.811827    1.117146  0.274344
# Средний модуль отклонения           0.688462    0.920277  0.209208
# Размах                              3.800000    5.060000  1.870000
# Дисперсия                           0.659062    1.248015  0.075265
#
#                                    Alcalinity of ash   Magnesium  \
# Max                                        30.000000  162.000000
# Min                                        10.600000   70.000000
# Среднее значение                           19.494944   99.741573
# ...

# %%
# Нормализация данных 3.9
(df-df.mean())/df.std()
# Out:
#       Alcohol  Malic acid       Ash  Alcalinity of ash  Magnesium  \
# 0    1.514341   -0.560668  0.231400          -1.166303   1.908522
# 1    0.245597   -0.498009 -0.825667          -2.483841   0.018094
# 2    0.196325    0.021172  1.106214          -0.267982   0.088110
# 3    1.686791   -0.345835  0.486554          -0.806975   0.928300
# 4    0.294868    0.227053  1.835226           0.450674   1.278379
# ..        ...         ...       ...                ...        ...
# 173  0.873810    2.966176  0.304301           0.300954  -0.331985
# 174  0.491955    1.408636  0.413653           1.049555   0.158126
# 175  0.331822    1.739837 -0.388260           0.151234   1.418411
# 176  0.208643    0.227053  0.012696           0.151234   1.418411
# 177  1.391162    1.578712  1.361368           1.498716  -0.261969
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0         0.806722    1.031908             -0.657708         1.221438
# ...

# %%
# Кодирование на гиперсферу 3.10
(df - df.min())/(df.max() - df.min())
# Out:
#       Alcohol  Malic acid       Ash  Alcalinity of ash  Magnesium  \
# 0    0.842105    0.191700  0.572193           0.257732   0.619565
# 1    0.571053    0.205534  0.417112           0.030928   0.326087
# 2    0.560526    0.320158  0.700535           0.412371   0.336957
# 3    0.878947    0.239130  0.609626           0.319588   0.467391
# 4    0.581579    0.365613  0.807487           0.536082   0.521739
# ..        ...         ...       ...                ...        ...
# 173  0.705263    0.970356  0.582888           0.510309   0.271739
# 174  0.623684    0.626482  0.598930           0.639175   0.347826
# 175  0.589474    0.699605  0.481283           0.484536   0.543478
# 176  0.563158    0.365613  0.540107           0.484536   0.543478
# 177  0.815789    0.664032  0.737968           0.716495   0.282609
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0         0.627586    0.573840              0.283019         0.593060
# ...

# %%
# Кодирование на гиперкуб 3.11
2 * (df - df.min()) / (df.max() - df.min()) - 1
# Out:
#       Alcohol  Malic acid       Ash  Alcalinity of ash  Magnesium  \
# 0    0.684211   -0.616601  0.144385          -0.484536   0.239130
# 1    0.142105   -0.588933 -0.165775          -0.938144  -0.347826
# 2    0.121053   -0.359684  0.401070          -0.175258  -0.326087
# 3    0.757895   -0.521739  0.219251          -0.360825  -0.065217
# 4    0.163158   -0.268775  0.614973           0.072165   0.043478
# ..        ...         ...       ...                ...        ...
# 173  0.410526    0.940711  0.165775           0.020619  -0.456522
# 174  0.247368    0.252964  0.197861           0.278351  -0.304348
# 175  0.178947    0.399209 -0.037433          -0.030928   0.086957
# 176  0.126316   -0.268775  0.080214          -0.030928   0.086957
# 177  0.631579    0.328063  0.475936           0.432990  -0.434783
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0         0.255172    0.147679             -0.433962         0.186120
# ...
